# %%
import spot
from spot.jupyter import display_inline
spot.setup(show_default='.bans')

# %% [markdown]
# Notebook contains parts of automaton worse_example1.hoa that are not equivalent after optimized simplification L2.

# %%
def show_one_difference(left, right):
    run = left.exclusive_run(right)
    if not run:
        print("The two automata are equivalent.")
    else:
        print("The following word is only accepted by one automaton:", spot.make_twa_word(run))
        run.highlight(5)
        display_inline(left, right)

# %%
for problem in spot.automata('problem'):
    display(problem)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fdc7a4a7600> >

# %%
for l1 in spot.automata('problem.L1'):
    display(l1)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fdc7a4a72d0> >

# %%
for l2 in spot.automata('problem.L2'):
    display(l2)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fdc7a4a7690> >
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fdc8805bb10> >
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fdc8805bc00> >

# %%
for p in spot.automata('problem'):
    display(p)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fdc7a4a7690> >

# %%
for p1 in spot.automata('problem.out'):
    display(p1)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7fdc7a4a7780> >
