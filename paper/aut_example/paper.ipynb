# %%
import spot
from spot.jupyter import display_inline
spot.setup(show_default='.bans')

# %%
for aut in spot.automata('./aut1.hoa'):
    display(aut)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f36a7fe3fc0> >

# %%
for l1 in spot.automata('./aut1.l1.hoa'):
    display(l1)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f36bc05f330> >

# %%
for l2 in spot.automata('./aut1.l2.hoa'):
    display(l2)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f36bc05f2d0> >

# %%
for l3 in spot.automata('./aut1.l3.hoa'):
    display(l3)
# Out:
# <spot.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f36bc05f4e0> >
